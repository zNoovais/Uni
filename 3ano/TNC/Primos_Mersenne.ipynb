# %%
def Lucas_Lehmer(p):
    if not is_prime(p):
        return False
    Mp = 2^p-1
    r = mod(4,Mp)
    for k in range(1,p-1):
        r = r^2-2
    return r == 0

# %%
Lucas_Lehmer(5)
# Out:
# True

# %%
power_mod(5,5,7)
# Out:
# 3

# %%
n = 17 
Zn = IntegerModRing(n)

# %%
r = Zn(3)

[.-
