# %%
def f(x):
    return x*x+1

print(f(101))

gcd(13603,10202)
# Out:
# 10202
# 1

# %%
gcd(143,21)
# Out:
# 1

# %%
26^2+1
# Out:
# 677

# %%
677%143
# Out:
# 105

# %%
105^2+1
# Out:
# 11026

# %%
11026%143
# Out:
# 15

# %%
gcd(143,11)
# Out:
# 11

# %%
143/11
# Out:
# 13

# %%
169 % 17
# Out:
# 16
